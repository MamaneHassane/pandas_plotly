# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv')

# %% [markdown]
# Remplacer les noms des colonnes, il faut toutes les remplacer avec cette méthode

# %%
# df.columns = ["one","two","three","four","five","six","seven","eight","nine"]
df
# Out:
#     first_name last_name                            email date_of_birth  \
# 0      hassane    mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4    Elizabeth    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages_know  answer
# ...

# %% [markdown]
# Mettre les noms en uppercase

# %%
# df.columns = [x.upper() for x in df.columns]
df
# Out:
#     first_name last_name                            email date_of_birth  \
# 0      hassane    mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4    Elizabeth    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages_know  answer
# ...

# %% [markdown]
# Enlever ou mettre des espaces

# %%
df.columns = df.columns.str.replace('_',' ')
df
# Out:
#     first name last name                            email date of birth  \
# 0      hassane    mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4    Elizabeth    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages know  answer
# ...

# %% [markdown]
# Changer les noms qu'on veut

# %%
df.rename(columns={'first name':'first', 'last name':'last'}, inplace=True)

# %%
df.iloc[0]
# Out:
# first                          hassane
# last                            mamane
# email             hassanemmn@gmail.com
# date of birth               16/02/2001
# salary                           12000
# field                        Data & IA
# sex                                  M
# languages know     python,java,c_sharp
# answer                            True
# Name: 0, dtype: object

# %%
df.loc[0,['first','last']] = ['housseini','Mamane']
df.loc[0]
# Out:
# first                        housseini
# last                            Mamane
# email             hassanemmn@gmail.com
# date of birth               16/02/2001
# salary                           12000
# field                        Data & IA
# sex                                  M
# languages know     python,java,c_sharp
# answer                            True
# Name: 0, dtype: object

# %%
df.at[0,'first'] = 'hassane'
df.loc[0]
# Out:
# first                          hassane
# last                            Mamane
# email             hassanemmn@gmail.com
# date of birth               16/02/2001
# salary                           12000
# field                        Data & IA
# sex                                  M
# languages know     python,java,c_sharp
# answer                            True
# Name: 0, dtype: object

# %% [markdown]
# Modifier toute une colonne

# %%
df['email'] = df['email'].str.lower()

# %% [markdown]
# Voir des informations

# %%
df['email'].apply(len)
# Out:
# 0      20
# 1      14
# 2      21
# 3      15
# 4      28
#        ..
# 995    24
# 996    16
# 997    29
# 998    31
# 999    17
# Name: email, Length: 1000, dtype: int64

# %%
def to_upper(word):
    return word.upper()
df['email'].apply(to_upper)
# Out:
# 0                 HASSANEMMN@GMAIL.COM
# 1                       SARA@GMAIL.COM
# 2                FRANCISESTL@GMAIL.COM
# 3                      LAURA@GMAIL.COM
# 4         ALEXANDERRAYMOND@GARCIA.INFO
#                     ...
# 995           CONNORHARRIS@HOTMAIL.COM
# 996                   KKLINE@RAMOS.BIZ
# 997      TRACEY52@REYES-WASHINGTON.COM
# 998    REYNOLDSJUSTIN@STEWART-HUNT.COM
# 999                  PAULLIU@YAHOO.COM
# Name: email, Length: 1000, dtype: object

# %%
df.apply(lambda x: x.count())
# Out:
# first             1000
# last              1000
# email             1000
# date of birth     1000
# salary            1000
# field             1000
# sex               1000
# languages know     745
# answer            1000
# dtype: int64

# %%
df['email'].min()
# Out:
# 'aacosta@hall.biz'

# %% [markdown]
# map : appliquer à chaque valeur

# %%
df.map(lambda x: type(x))
# Out:
#              first           last          email  date of birth  \
# 0    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 1    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 2    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 3    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 4    <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# ..             ...            ...            ...            ...
# 995  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 996  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 997  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 998  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 999  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
#
#             salary          field            sex   languages know  \
# 0    <class 'int'>  <class 'str'>  <class 'str'>    <class 'str'>
# ...

# %%
df['answer'] = df['answer'].infer_objects({True: 1, False: 0})

# %%
df
# Out:
#          first      last                            email date of birth  \
# 0    housseini    Mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4        Elisa    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999      Elisa     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages know  answer
# ...

# %%
df.loc[0,'first'] = 'hassane'
df['first']
# Out:
# 0      hassane
# 1         sara
# 2      francis
# 3        laura
# 4        Elisa
#         ...
# 995      Jason
# 996      Ricky
# 997    Brandon
# 998       Mark
# 999      Elisa
# Name: first, Length: 1000, dtype: object
