# %%
import pandas as pd

# %%
data = pd.read_csv('data/data.csv')
df = pd.DataFrame(data)
df
# Out:
#     first_name last_name                            email date_of_birth  \
# 0      hassane    mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4    Elizabeth    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages_know  answer
# ...

# %% [markdown]
# Trier par colonnes et/ou ordre

# %%
df.sort_values(by=['first_name', 'last_name'], ascending=True, inplace=True)
df
# Out:
#     first_name last_name                                email date_of_birth  \
# 899      Aaron  Cummings        elaine41@sherman-figueroa.org    07/09/2003
# 355      Aaron   Ellison          andersonalexander@gmail.com    13/04/2001
# 743      Aaron  Gonzales                  walkerkim@gmail.com    10/04/2001
# 515      Aaron     Sharp            samueljackson@hopkins.com    23/01/1995
# 190    Abigail    Gordon  thomasjeremy@blackburn-morrison.com    17/04/1997
# ..         ...       ...                                  ...           ...
# 33     Zachary     Scott         ifuller@charles-mcdaniel.org    05/06/2005
# 2      francis   eustler                francisestl@gmail.com    30/07/2002
# 0      hassane    mamane                 hassanemmn@gmail.com    16/02/2001
# 3        laura    chavez                      laura@gmail.com    14/10/2003
# 1         sara    tamami                       sara@gmail.com    21/03/2001
#
# ...

# %%
df.sort_values(by=['first_name', 'last_name'], ascending=[True, False])
df
# Out:
#     first_name last_name                                email date_of_birth  \
# 899      Aaron  Cummings        elaine41@sherman-figueroa.org    07/09/2003
# 355      Aaron   Ellison          andersonalexander@gmail.com    13/04/2001
# 743      Aaron  Gonzales                  walkerkim@gmail.com    10/04/2001
# 515      Aaron     Sharp            samueljackson@hopkins.com    23/01/1995
# 190    Abigail    Gordon  thomasjeremy@blackburn-morrison.com    17/04/1997
# ..         ...       ...                                  ...           ...
# 33     Zachary     Scott         ifuller@charles-mcdaniel.org    05/06/2005
# 2      francis   eustler                francisestl@gmail.com    30/07/2002
# 0      hassane    mamane                 hassanemmn@gmail.com    16/02/2001
# 3        laura    chavez                      laura@gmail.com    14/10/2003
# 1         sara    tamami                       sara@gmail.com    21/03/2001
#
# ...

# %% [markdown]
# Remettre à défaut

# %%
df.sort_index(ascending=True, inplace=True)
df
# Out:
#     first_name last_name                            email date_of_birth  \
# 0      hassane    mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4    Elizabeth    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages_know  answer
# ...

# %% [markdown]
# Trier une colonne

# %%
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], dayfirst=True)
df['date_of_birth'].sort_values()
# Out:
# 592   1993-10-27
# 804   1993-10-29
# 542   1993-11-05
# 328   1993-11-07
# 965   1993-11-17
#          ...
# 527   2006-10-08
# 229   2006-10-10
# 98    2006-10-12
# 623   2006-10-19
# 471   2006-10-22
# Name: date_of_birth, Length: 1000, dtype: datetime64[ns]

# %% [markdown]
# Une petite analyse des salaires

# %%
largest_salaries = df['salary'].nlargest(100).index
df.loc[largest_salaries]
# Out:
#       first_name   last_name                      email date_of_birth  salary  \
# 95          Alex      Bryant        xhorton@hotmail.com    1997-12-19   14976
# 18       Tiffany      Miller        richard86@gmail.com    2000-06-26   14970
# 536     Michelle      Vargas      jamiegolden@gmail.com    2003-01-23   14969
# 911       Robert      Palmer      mariataylor@riley.biz    2001-12-22   14966
# 222        Emily     Beasley  davealexander@hotmail.com    1997-04-07   14953
# ..           ...         ...                        ...           ...     ...
# 338       Leslie       Barry  conleynatalie@hotmail.com    1996-05-05   14413
# 909       Brenda       Brown       bfernandez@young.com    1999-03-02   14409
# 314         Cody      Wright      katherine63@gmail.com    1994-07-09   14407
# 356          Amy      Barton          amiller@gmail.com    2002-12-10   14407
# 480  Christopher  Pennington           carly42@best.org    1997-02-11   14401
#
# ...

# %%
salaire_par_domaines = df[['field', 'salary']]
salaire_par_domaines.sort_values(by=['field', 'salary'], ascending=[True, True])
# Out:
#                     field  salary
# 761                   Art    8046
# 604                   Art    8218
# 189                   Art    8220
# 949                   Art    8232
# 770                   Art    8261
# ..                    ...     ...
# 931  Software engineering   14782
# 34   Software engineering   14804
# 889  Software engineering   14884
# 44   Software engineering   14897
# 18   Software engineering   14970
#
# [1000 rows x 2 columns]
