# %% [markdown]
# Importer les packages nécéssaires

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 10)

# %%
df = pd.read_csv('data/data.csv')

df
# Out:
#     first_name last_name                            email date_of_birth  \
# 0      hassane    mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4    Elizabeth    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages_know  answer
# ...

# %% [markdown]
# Voir les premières lignes

# %%
df.head(3)
# Out:
#   first_name last_name                  email date_of_birth  salary  \
# 0    hassane    mamane   hassanemmn@gmail.com    16/02/2001   12000
# 1       sara    tamami         sara@gmail.com    21/03/2001    9700
# 2    francis   eustler  francisestl@gmail.com    30/07/2002    9500
#
#                   field sex       languages_know  answer
# 0             Data & IA   M  python,java,c_sharp    True
# 1  Software engineering   F         python,R,c++   False
# 2            Literature   M           php,java,c   False

# %% [markdown]
# Voir les dernières lignes

# %%
df.tail(3)
# Out:
#     first_name last_name                            email date_of_birth  \
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex languages_know  answer
# 997   10870  Software engineering   M  c_sharp,php,R   False
# 998   12625             Data & IA   F         c,java    True
# 999   10026               Science   F            NaN   False

# %% [markdown]
# Compte des lignes et des colonnes

# %%
df.count
# Out:
# <bound method DataFrame.count of     first_name last_name                            email date_of_birth  \
# 0      hassane    mamane             hassanemmn@gmail.com    16/02/2001
# 1         sara    tamami                   sara@gmail.com    21/03/2001
# 2      francis   eustler            francisestl@gmail.com    30/07/2002
# 3        laura    chavez                  laura@gmail.com    14/10/2003
# 4    Elizabeth    Taylor     alexanderraymond@garcia.info    22/11/2000
# ..         ...       ...                              ...           ...
# 995      Jason  Martinez         connorharris@hotmail.com    12/08/2006
# 996      Ricky   Mendoza                 kkline@ramos.biz    25/08/2001
# 997    Brandon    Harris    tracey52@reyes-washington.com    18/01/2000
# 998       Mark   Johnson  reynoldsjustin@stewart-hunt.com    04/02/1997
# 999  Elizabeth     Flynn                paulliu@yahoo.com    13/04/1994
#
#      salary                 field sex       languages_know  answer
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.shape[0] # lignes
# Out:
# 1000

# %%
df.shape[1] # colonnes
# Out:
# 9

# %% [markdown]
# Voir des informations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   first_name      1000 non-null   object
#  1   last_name       1000 non-null   object
#  2   email           1000 non-null   object
#  3   date_of_birth   1000 non-null   object
#  4   salary          1000 non-null   int64
#  5   field           1000 non-null   object
#  6   sex             1000 non-null   object
#  7   languages_know  745 non-null    object
#  8   answer          1000 non-null   bool
# dtypes: bool(1), int64(1), object(7)
# memory usage: 63.6+ KB

# %%
df2 = pd.read_csv("data/data.csv", index_col='field')
df2
# Out:
#                      first_name last_name                            email  \
# field
# Data & IA               hassane    mamane             hassanemmn@gmail.com
# Software engineering       sara    tamami                   sara@gmail.com
# Literature              francis   eustler            francisestl@gmail.com
# Art                       laura    chavez                  laura@gmail.com
# Science               Elizabeth    Taylor     alexanderraymond@garcia.info
# ...                         ...       ...                              ...
# Science                   Jason  Martinez         connorharris@hotmail.com
# Literature                Ricky   Mendoza                 kkline@ramos.biz
# Software engineering    Brandon    Harris    tracey52@reyes-washington.com
# Data & IA                  Mark   Johnson  reynoldsjustin@stewart-hunt.com
# Science               Elizabeth     Flynn                paulliu@yahoo.com
#
# ...

# %% [markdown]
# On peut classer les indexes, par défaut l'ordre est ascendant

# %%
df2.sort_index(ascending=False, inplace=True)
df2
# Out:
#                        first_name last_name                            email  \
# field
# Software engineering        Tyler     Stone                yhorton@yahoo.com
# Software engineering         Eric   Griffin                  bcruz@gmail.com
# Software engineering      Crystal     Mcgee            jamesjones@thomas.org
# Software engineering      Matthew   Holland               scharles@gmail.com
# Software engineering       Austin      Moss        christopher28@hotmail.com
# ...                           ...       ...                              ...
# Art                        Donald     Keith               tara45@hotmail.com
# Art                   Christopher      Rose             burchrobin@yahoo.com
# Art                        Harold  Williams      kathryn11@cooper-stokes.org
# Art                     Katherine    Romero               tsanchez@yahoo.com
# Art                         Heidi      Hays  kimberly66@steele-rodriguez.biz
#
# ...
